#   inflating: KEMDy19/wav/Session18/Sess18_impro02/Sess18_impro02_F012.wav
#   inflating: KEMDy19/wav/Session18/Sess18_impro02/Sess18_impro02_F013.csv
# ...
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M006.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M006.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M007.csv
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M007.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M007.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M008.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M008.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M008.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M009.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M009.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M009.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M010.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M010.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M010.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M011.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M011.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M011.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M012.csv
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M012.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M012.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M013.csv
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M013.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M013.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M014.csv
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M014.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M014.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M015.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M015.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M015.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M016.csv
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M016.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M016.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M017.csv
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M017.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M017.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M018.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M018.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M018.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M019.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M019.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script05/Sess20_script05_M019.wav
#    creating: KEMDy19/wav/Session20/Sess20_script06/
#    creating: KEMDy19/wav/Session20/Sess20_script06/converted/
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F001.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F001.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F001.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F002.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F002.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F002.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F003.csv
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F003.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F003.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F004.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F004.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F004.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F005.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F005.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F005.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F006.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F006.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F006.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F007.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F007.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F007.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F008.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F008.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F008.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F009.csv
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F009.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F009.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F010.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F010.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F010.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F011.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F011.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F011.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F012.csv
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F012.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F012.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F013.csv
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F013.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F013.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F014.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F014.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F014.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F015.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F015.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F015.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F016.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F016.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F016.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F017.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F017.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F017.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F018.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F018.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F018.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F019.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F019.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F019.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F020.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F020.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F020.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F021.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F021.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F021.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F022.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F022.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_F022.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M001.csv
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M001.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M001.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M002.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M002.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M002.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M003.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M003.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M003.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M004.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M004.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M004.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M005.csv
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M005.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M005.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M006.csv
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M006.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M006.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M007.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M007.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M007.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M008.csv
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M008.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M008.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M009.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M009.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M009.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M010.csv
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M010.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M010.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M011.csv
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M011.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M011.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M012.csv
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M012.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M012.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M013.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M013.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M013.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M014.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M014.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M014.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M015.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M015.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M015.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M016.csv
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M016.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M016.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M017.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M017.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M017.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M018.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M018.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M018.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M019.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M019.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M019.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M020.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M020.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M020.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M021.csv
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M021.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M021.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M022.csv
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M022.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M022.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M023.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M023.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M023.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M024.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M024.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M024.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M025.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M025.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M025.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M026.csv
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M026.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M026.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M027.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M027.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M027.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M028.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M028.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M028.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M029.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M029.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M029.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M030.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M030.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M030.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M031.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M031.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M031.wav
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M032.csv
#  extracting: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M032.txt
#   inflating: KEMDy19/wav/Session20/Sess20_script06/Sess20_script06_M032.wav

# %%
# !pip install transformers datasets
# Out:
# Collecting transformers
#   Downloading transformers-4.18.0-py3-none-any.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 16.3 MB/s
# Collecting datasets
#   Downloading datasets-2.1.0-py3-none-any.whl (325 kB)
#      |████████████████████████████████| 325 kB 69.2 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.5.1-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 8.4 MB/s
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 52.5 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.6.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.3)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 80.1 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Collecting sacremoses
#   Downloading sacremoses-0.0.49-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 75.8 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.8)
# Requirement already satisfied: pyarrow>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.12.2)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 56.1 MB/s
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.4)
# Collecting fsspec[http]>=2021.05.0
#   Downloading fsspec-2022.3.0-py3-none-any.whl (136 kB)
#      |████████████████████████████████| 136 kB 72.9 MB/s
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 78.4 MB/s
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 74.1 MB/s
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 77.0 MB/s
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (21.4.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.7 MB/s
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 69.8 MB/s
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Installing collected packages: multidict, frozenlist, yarl, urllib3, asynctest, async-timeout, aiosignal, pyyaml, fsspec, aiohttp, xxhash, tokenizers, sacremoses, responses, huggingface-hub, transformers, datasets
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.2 asynctest-0.13.0 datasets-2.1.0 frozenlist-1.3.0 fsspec-2022.3.0 huggingface-hub-0.5.1 multidict-6.0.2 pyyaml-6.0 responses-0.18.0 sacremoses-0.0.49 tokenizers-0.12.1 transformers-4.18.0 urllib3-1.25.11 xxhash-3.0.0 yarl-1.7.2

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
import sys
import warnings
import re

import numpy as np
import pandas as pd

import datasets
from datasets import load_metric
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer

from sklearn.model_selection import train_test_split

import torch
from torch.utils.data import Dataset, DataLoader

import seaborn as sns

warnings.filterwarnings(action='ignore')

# %%
PRETRAINED_ROBERTA = 'klue/roberta-large'
TEXT_MAX_LENGTH = 249
NUM_LABELS = 7

# %%
class MultiModalDataset(Dataset):
    
    def __init__(self, 
                 data_path: str, 
                 pretrained_roberta: str,  
                 text_max_length: int, 
                 num_labels: int):
        super(MultiModalDataset, self).__init__()
        self.data_path = data_path
        self.text_tokenizer = AutoTokenizer.from_pretrained(pretrained_roberta, use_fast=True)
        self.text_model = AutoModelForSequenceClassification.from_pretrained(pretrained_roberta, num_labels=num_labels, output_hidden_states=False)
        self.text_max_length = text_max_length
        self.text, self.labels = self.load_data(self.data_path)
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        normalized_text = self.normalize_string(self.text[idx])
        text_input = self.tokenize_text(normalized_text)
        text_data = {k: torch.tensor(v).squeeze() for k, v in text_input.items()}
        text_data['labels'] = torch.tensor(self.labels[idx])
        return text_data    
    
    def tokenize_text(self, text):
        tokenized_text = self.text_tokenizer(text,
                                            max_length = self.text_max_length,
                                            padding="max_length",
                                            truncation=True, 
                                            return_tensors="pt")
        return tokenized_text
    
    @staticmethod
    def normalize_string(text):
        text = re.sub(r"[\s]", r" ", str(text))
        text = re.sub(r"[^a-zA-Z가-힣ㄱ-ㅎ0-9.!?]+", r" ", str(text))
        return text

    @staticmethod
    def load_data(data_path: str):
        data = pd.read_pickle(data_path)
        data = data.dropna()
        text = list(data['text'])
        labels = list(data['emotion'])
        return text, labels

# %%
data_train = MultiModalDataset(data_path='path_train.pkl', 
                               pretrained_roberta=PRETRAINED_ROBERTA, 
                               text_max_length=TEXT_MAX_LENGTH,
                               num_labels=NUM_LABELS)
data_val = MultiModalDataset(data_path='path_dev.pkl', 
                               pretrained_roberta=PRETRAINED_ROBERTA, 
                               text_max_length=TEXT_MAX_LENGTH,
                               num_labels=NUM_LABELS)
data_test = MultiModalDataset(data_path='path_test.pkl', 
                               pretrained_roberta=PRETRAINED_ROBERTA, 
                               text_max_length=TEXT_MAX_LENGTH,
                               num_labels=NUM_LABELS)
# Out:
# Some weights of the model checkpoint at klue/roberta-large were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at klue/roberta-large and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of the model checkpoint at klue/roberta-large were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at klue/roberta-large and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of the model checkpoint at klue/roberta-large were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at klue/roberta-large and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
tokenizer = AutoTokenizer.from_pretrained(PRETRAINED_ROBERTA, use_fast=True)

# %%
import gc
gc.collect()
# Out:
# 903

# %%
metric = load_metric("glue", "mnli")

# %%
def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    predictions = np.argmax(predictions, axis=1)
    return metric.compute(predictions=predictions, references=labels)

# %%
def model_init():
    return AutoModelForSequenceClassification.from_pretrained(PRETRAINED_ROBERTA, num_labels=NUM_LABELS, output_hidden_states=False)

# %%
metric_name = "accuracy"

args = TrainingArguments(
    "saved",
    evaluation_strategy="epoch",
    save_strategy='epoch',
    learning_rate=2e-05,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=5,
    weight_decay=0.01,
    load_best_model_at_end=True,
    metric_for_best_model=metric_name,
    greater_is_better=True,
    seed = 42
)

# %%
trainer = Trainer(
    model_init=model_init,
    args=args,
    train_dataset=data_train,
    eval_dataset=data_val,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)
# Out:
# loading configuration file https://huggingface.co/klue/roberta-large/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/571e05a2160c18c93365862223c4dae92bbd1b41464a4bd5f372ad703dba6097.ae5b7f8d8a28a3ff0b1560b4d08c6c3bd80f627288eee2024e02959dd60380d0
# Model config RobertaConfig {
#   "_name_or_path": "klue/roberta-large",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2",
#     "3": "LABEL_3",
#     "4": "LABEL_4",
#     "5": "LABEL_5",
#     "6": "LABEL_6"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2,
#     "LABEL_3": 3,
#     "LABEL_4": 4,
#     "LABEL_5": 5,
#     "LABEL_6": 6
#   },
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "tokenizer_class": "BertTokenizer",
#   "transformers_version": "4.18.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 32000
# }
#
# loading weights file https://huggingface.co/klue/roberta-large/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/fd91c85effc137c99cd14cfe5c3459faa223c005b1577dc2c5aa48f6b2c4fbb1.3d5d467e78cd19d9a87029910ed83289edde0111a75a41e0cc79ad3fc06e4a51
# Some weights of the model checkpoint at klue/roberta-large were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at klue/roberta-large and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
trainer.train()
# Out:
# loading configuration file https://huggingface.co/klue/roberta-large/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/571e05a2160c18c93365862223c4dae92bbd1b41464a4bd5f372ad703dba6097.ae5b7f8d8a28a3ff0b1560b4d08c6c3bd80f627288eee2024e02959dd60380d0
# Model config RobertaConfig {
#   "_name_or_path": "klue/roberta-large",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2",
#     "3": "LABEL_3",
#     "4": "LABEL_4",
#     "5": "LABEL_5",
#     "6": "LABEL_6"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2,
#     "LABEL_3": 3,
#     "LABEL_4": 4,
#     "LABEL_5": 5,
#     "LABEL_6": 6
#   },
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "tokenizer_class": "BertTokenizer",
#   "transformers_version": "4.18.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 32000
# }
#
# loading weights file https://huggingface.co/klue/roberta-large/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/fd91c85effc137c99cd14cfe5c3459faa223c005b1577dc2c5aa48f6b2c4fbb1.3d5d467e78cd19d9a87029910ed83289edde0111a75a41e0cc79ad3fc06e4a51
# Some weights of the model checkpoint at klue/roberta-large were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at klue/roberta-large and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ***** Running training *****
#   Num examples = 6575
#   Num Epochs = 5
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 4110
#     <div>
#
#       <progress value='4110' max='4110' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4110/4110 1:45:33, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.186800</td>
#       <td>0.865234</td>
#       <td>0.691606</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.697200</td>
#       <td>0.848999</td>
#       <td>0.715937</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.574100</td>
#       <td>0.934236</td>
#       <td>0.719586</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.415200</td>
#       <td>1.057345</td>
#       <td>0.717153</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.308300</td>
#       <td>1.187518</td>
#       <td>0.723236</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 1644
#   Batch size = 8
# Saving model checkpoint to saved/checkpoint-822
# Configuration saved in saved/checkpoint-822/config.json
# Model weights saved in saved/checkpoint-822/pytorch_model.bin
# tokenizer config file saved in saved/checkpoint-822/tokenizer_config.json
# Special tokens file saved in saved/checkpoint-822/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1644
#   Batch size = 8
# Saving model checkpoint to saved/checkpoint-1644
# Configuration saved in saved/checkpoint-1644/config.json
# Model weights saved in saved/checkpoint-1644/pytorch_model.bin
# tokenizer config file saved in saved/checkpoint-1644/tokenizer_config.json
# Special tokens file saved in saved/checkpoint-1644/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1644
#   Batch size = 8
# Saving model checkpoint to saved/checkpoint-2466
# Configuration saved in saved/checkpoint-2466/config.json
# Model weights saved in saved/checkpoint-2466/pytorch_model.bin
# tokenizer config file saved in saved/checkpoint-2466/tokenizer_config.json
# Special tokens file saved in saved/checkpoint-2466/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1644
#   Batch size = 8
# Saving model checkpoint to saved/checkpoint-3288
# Configuration saved in saved/checkpoint-3288/config.json
# Model weights saved in saved/checkpoint-3288/pytorch_model.bin
# tokenizer config file saved in saved/checkpoint-3288/tokenizer_config.json
# Special tokens file saved in saved/checkpoint-3288/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1644
#   Batch size = 8
# Saving model checkpoint to saved/checkpoint-4110
# Configuration saved in saved/checkpoint-4110/config.json
# Model weights saved in saved/checkpoint-4110/pytorch_model.bin
# tokenizer config file saved in saved/checkpoint-4110/tokenizer_config.json
# Special tokens file saved in saved/checkpoint-4110/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from saved/checkpoint-4110 (score: 0.7232360097323601).
# TrainOutput(global_step=4110, training_loss=0.6033595082823667, metrics={'train_runtime': 6335.087, 'train_samples_per_second': 5.189, 'train_steps_per_second': 0.649, 'total_flos': 1.490000493593475e+16, 'train_loss': 0.6033595082823667, 'epoch': 5.0})

# %%
trainer.evaluate()
# Out:
# ***** Running Evaluation *****
#   Num examples = 1644
#   Batch size = 8
#     <div>
#
#       <progress value='206' max='206' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [206/206 01:30]
#     </div>
# {'epoch': 5.0,
#  'eval_accuracy': 0.7232360097323601,
#  'eval_loss': 1.1875184774398804,
#  'eval_runtime': 90.6653,
#  'eval_samples_per_second': 18.133,
#  'eval_steps_per_second': 2.272}

# %%
pred = trainer.predict(data_test)
# Out:
# ***** Running Prediction *****
#   Num examples = 2055
#   Batch size = 8
#     <div>
#
#       <progress value='720' max='206' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [206/206 09:14]
#     </div>

# %%
pred
# Out:
# PredictionOutput(predictions=array([[ 4.2237697 ,  5.0857825 , -2.2794783 , ..., -2.0746925 ,
#         -1.7009395 , -2.3078198 ],
#        [ 3.4805222 , -1.2829148 , -2.4359221 , ..., -3.7235756 ,
#         -1.5269098 ,  0.32847974],
#        [ 1.067754  , -0.9923486 , -0.8863773 , ..., -1.2146715 ,
#          6.3959737 , -2.8342047 ],
#        ...,
#        [ 7.21782   , -0.30942732, -2.0715668 , ..., -2.5429811 ,
#         -0.75715685, -1.0485512 ],
#        [-1.102238  , -1.5349534 , -1.0054612 , ..., -0.93647987,
#         -1.2439367 , -1.1644173 ],
#        [ 2.628472  ,  0.79952085,  0.6529304 , ..., -2.173507  ,
#         -0.7308053 , -1.4088047 ]], dtype=float32), label_ids=array([1, 0, 5, ..., 0, 3, 2]), metrics={'test_loss': 1.121650218963623, 'test_accuracy': 0.7250608272506083, 'test_runtime': 113.615, 'test_samples_per_second': 18.087, 'test_steps_per_second': 2.262})

# %%
predictions = pred.predictions
predictions
# Out:
# array([[ 4.2237697 ,  5.0857825 , -2.2794783 , ..., -2.0746925 ,
#         -1.7009395 , -2.3078198 ],
#        [ 3.4805222 , -1.2829148 , -2.4359221 , ..., -3.7235756 ,
#         -1.5269098 ,  0.32847974],
#        [ 1.067754  , -0.9923486 , -0.8863773 , ..., -1.2146715 ,
#          6.3959737 , -2.8342047 ],
#        ...,
#        [ 7.21782   , -0.30942732, -2.0715668 , ..., -2.5429811 ,
#         -0.75715685, -1.0485512 ],
#        [-1.102238  , -1.5349534 , -1.0054612 , ..., -0.93647987,
#         -1.2439367 , -1.1644173 ],
#        [ 2.628472  ,  0.79952085,  0.6529304 , ..., -2.173507  ,
#         -0.7308053 , -1.4088047 ]], dtype=float32)

# %%
np.save("/gdrive/ETRI/npy/pred_roberta_large_whole_1.npy", predictions)

# %%
test = pd.read_pickle('path_test.pkl')

# %%
test = test.dropna()

# %%
len(test['emotion'])
# Out:
# 2055

# %%
y_pred = np.argmax(predictions,1)
test['pred'] = y_pred

# %%
test.head()
# Out:
#                                              total_path  \
# 4039  ./KEMDy19/wav/Session08/Sess08_impro02/Sess08_...
# 7262  ./KEMDy19/wav/Session15/Sess15_script01/Sess15...
# 529   ./KEMDy19/wav/Session02/Sess02_script02/Sess02...
# 4541  ./KEMDy19/wav/Session09/Sess09_impro01/Sess09_...
# 2924  ./KEMDy19/wav/Session06/Sess06_impro01/Sess06_...
#
#                                                    text  emotion  pred
# 4039           l/ 내가 아주 아주 아주 듬뿍 발라줄게 그 약 가져와봐. (어딨냐)\n        1     1
# 7262                                    n/ 뭐야 나 말 안해.\n        0     3
# 529   b/ u/ 미안해. 우리 아버지는 음 음 음 3년동안 폐암으로 병원에 계시다가 돌아...        5     5
# 4541  아 그니까 그  김 부장이 또 나한테 막 뭐라했단 말이야 왜 맨날 나한테는 뭐라고만...        3     3
# 2924  아이 나 참 u/ 아이 나 피곤해. 어? 그 나 내일 u/ 일찍 자야돼. 나 내일 ...        0     0

# %%
labels = test.emotion.tolist()
preds = test.pred.tolist()
count = 0
for i, j in zip(labels, preds):
  if i == j:
    count += 1
  else:
    pass
acc = count / len(labels) * 100
acc
# Out:
# 72.50608272506082

# %%
# !cp -r ./saved/checkpoint-4110 /gdrive/ETRI/backup/roberta_large

# %% [markdown]
# 참고문헌
# transformers 공식문서 How to fine-tune a model on text classification
# https://github.com/huggingface/notebooks/blob/master/examples/text_classification.ipynb
