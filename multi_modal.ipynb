# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Fri May  6 04:33:29 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !ln -s /content/drive/MyDrive/ /gdrive

# %%
# !cp /gdrive/multi_modal.zip ./

# %%
# !unzip multi_modal3.zip
# Out:
# Archive:  multi_modal3.zip
#    creating: checkpoint/hubert_large/
#    creating: checkpoint/roberta_large/
#   inflating: configs/callbacks/default.yaml
#   inflating: configs/dataset/dataset.yaml
#   inflating: configs/hydra/default.yaml
#   inflating: configs/logger/wandb.yaml
#   inflating: configs/pl_module/pl_module.yaml
#   inflating: configs/trainer/default.yaml
#   inflating: configs/train.yaml
#   inflating: path_data/path_data.csv
#   inflating: path_data/path_test.pkl
#   inflating: path_data/path_train.pkl
#   inflating: path_data/path_val.pkl
#   inflating: src/__pycache__/dataset.cpython-39.pyc
#   inflating: src/__pycache__/model.cpython-39.pyc
#   inflating: src/__pycache__/pl_module.cpython-39.pyc
#   inflating: src/__pycache__/setup.cpython-39.pyc
#   inflating: src/dataset.py
#   inflating: src/model.py
#   inflating: src/pl_module.py
#   inflating: src/setup.py
#  extracting: .env
#  extracting: .gitignore
#   inflating: train.py

# %%
# !cp -r /gdrive/ETRI/backup/hubert_large/checkpoint-4110 ./checkpoint/hubert_large/
# !cp -r /gdrive/ETRI/backup/roberta_large/checkpoint-4110 ./checkpoint/roberta_large/
# !cp /gdrive/ETRI/KEMDy19.zip ./

# %%
# !unzip KEMDy19.zip
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: KEMDy19/wav/Session17/Sess17_script04/Sess17_script04_M011.wav
#   inflating: KEMDy19/wav/Session17/Sess17_script04/Sess17_script04_M012.csv
#   inflating: KEMDy19/wav/Session17/Sess17_script04/Sess17_script04_M012.txt
#   inflating: KEMDy19/wav/Session17/Sess17_script04/Sess17_script04_M012.wav
#   inflating: KEMDy19/wav/Session17/Sess17_script04/Sess17_script04_M013.csv
#  extracting: KEMDy19/wav/Session17/Sess17_script04/Sess17_script04_M013.txt
#   inflating: KEMDy19/wav/Session17/Sess17_script04/Sess17_script04_M013.wav
#   inflating: KEMDy19/wav/Session17/Sess17_script04/Sess17_script04_M014.csv
#   inflating: KEMDy19/wav/Session17/Sess17_script04/Sess17_script04_M014.txt
#   inflating: KEMDy19/wav/Session17/Sess17_script04/Sess17_script04_M014.wav
#   inflating: KEMDy19/wav/Session17/Sess17_script04/Sess17_script04_M015.csv
#   inflating: KEMDy19/wav/Session17/Sess17_script04/Sess17_script04_M015.txt
# ...

# %%
# !pip install colab_ssh --upgrade transformers datasets librosa fairseq omegaconf hydra python-dotenv pytorch_lightning wandb
# Out:
# ...
#      |████████████████████████████████| 4.0 MB 7.7 MB/s
# ...
#      |████████████████████████████████| 325 kB 75.2 MB/s
# ...
#      |████████████████████████████████| 213 kB 76.1 MB/s
# ...
#      |████████████████████████████████| 1.7 MB 59.6 MB/s
# ...
#      |████████████████████████████████| 74 kB 4.0 MB/s
# ...
#      |████████████████████████████████| 82 kB 850 kB/s
# ...
#      |████████████████████████████████| 584 kB 80.4 MB/s
# ...
#      |████████████████████████████████| 1.8 MB 57.5 MB/s
# ...
#      |████████████████████████████████| 596 kB 71.5 MB/s
# ...
#      |████████████████████████████████| 880 kB 58.5 MB/s
# ...
#      |████████████████████████████████| 77 kB 8.6 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 67.0 MB/s
# ...
#      |████████████████████████████████| 136 kB 92.5 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 66.6 MB/s
# ...
#      |████████████████████████████████| 212 kB 92.8 MB/s
# ...
#      |████████████████████████████████| 127 kB 93.6 MB/s
# ...
#      |████████████████████████████████| 90 kB 13.4 MB/s
# ...

# %%
import pandas as pd

train = pd.read_pickle('./path_data/path_train.pkl')
val = pd.read_pickle('./path_data/path_val.pkl')
test = pd.read_pickle('./path_data/path_test.pkl')

# %%
train['total_path'] = train['total_path'].apply(lambda x: '/content' + x[1:])
train.head()
# Out:
#                                              total_path  \
# 1146  /content/KEMDy19/wav/Session03/Sess03_script06...
# 9420  /content/KEMDy19/wav/Session19/Sess19_impro03/...
# 9753  /content/KEMDy19/wav/Session19/Sess19_impro04/...
# 9303  /content/KEMDy19/wav/Session19/Sess19_script04...
# 3780  /content/KEMDy19/wav/Session08/Sess08_impro02/...
#
#                                                    text  emotion
# 1146  b/ 사랑하는 오빠 나 잊지마? 어? 나 잊으면 안돼? b/ 어 나 b/ 아 마침 ...        1
# 9420                                               네?\n        2
# 9753                  아이 갑자기 그렇게 말하니까 당연히 걱정되지 이 사람아.\n        0
# 9303                             어때? 난 오빠 여잔데 내가 부끄러?\n        0
# 3780                                           나 사랑해?\n        1

# %%
val['total_path'] = val['total_path'].apply(lambda x: '/content' + x[1:])
val.head()
# Out:
#                                              total_path  \
# 6119  /content/KEMDy19/wav/Session12/Sess12_impro01/...
# 6619  /content/KEMDy19/wav/Session13/Sess13_script06...
# 2137  /content/KEMDy19/wav/Session05/Sess05_script04...
# 1678  /content/KEMDy19/wav/Session04/Sess04_script06...
# 8832  /content/KEMDy19/wav/Session18/Sess18_script04...
#
#                                                    text  emotion
# 6119                                           무슨 생각?\n        0
# 6619                                               어.\n        0
# 2137  (해보자고 u/+아 지금 생각할 게) 뭐가 있어. 지섭씬 여기 있어. 일단 내가 가...        3
# 1678  o/ N/ 아 알았어. 알았어. 걱정하지마. 내가 입이 무겁잖아. 그러니까 신상 구...        1
# 8832                                            아 뭐야.\n        3

# %%
test['total_path'] = test['total_path'].apply(lambda x: '/content' + x[1:])
test.head()
# Out:
#                                              total_path  \
# 4039  /content/KEMDy19/wav/Session08/Sess08_impro02/...
# 7262  /content/KEMDy19/wav/Session15/Sess15_script01...
# 529   /content/KEMDy19/wav/Session02/Sess02_script02...
# 4541  /content/KEMDy19/wav/Session09/Sess09_impro01/...
# 2924  /content/KEMDy19/wav/Session06/Sess06_impro01/...
#
#                                                    text  emotion
# 4039           l/ 내가 아주 아주 아주 듬뿍 발라줄게 그 약 가져와봐. (어딨냐)\n        1
# 7262                                    n/ 뭐야 나 말 안해.\n        0
# 529   b/ u/ 미안해. 우리 아버지는 음 음 음 3년동안 폐암으로 병원에 계시다가 돌아...        5
# 4541  아 그니까 그  김 부장이 또 나한테 막 뭐라했단 말이야 왜 맨날 나한테는 뭐라고만...        3
# 2924  아이 나 참 u/ 아이 나 피곤해. 어? 그 나 내일 u/ 일찍 자야돼. 나 내일 ...        0

# %%
train.to_pickle('./path_data/path_train2.pkl')
val.to_pickle('./path_data/path_val2.pkl')
test.to_pickle('./path_data/path_test2.pkl')

# %%
from colab_ssh import launch_ssh_cloudflared, init_git_cloudflared
launch_ssh_cloudflared(password="password")
# Out:
# <style>
# *{
# 	outline:none;
# }
# code{
# 	display:inline-block;
# 	padding:5px 10px;
# 	background: #444;
# 	border-radius: 4px;
# 	white-space: pre-wrap;
# 	position:relative;
# 	color:white;
# }
# .copy-code-button{
# 	float:right;
# 	background:#333;
# 	color:white;
# 	border: none;
# 	margin: 0 0 0 10px;
# 	cursor: pointer;
# }
# p, li{
# 	max-width:700px;
# }
# .choices{
# 	display:flex;
# 	flex: 1 0 auto;
# }
# .choice-section{
# 	border:solid 1px #555;
# 	border-radius: 4px;
# 	min-width:300px;
# 	margin: 10px 15px 0 0;
# 	padding: 0 15px 15px 15px ;
# }
# .button{
# 	padding: 10px 15px;
# 	background:#333;
# 	border-radius: 4px;
# 	border:solid 1px #555;
# 	color:white;
# 	font-weight:bold;
# 	cursor:pointer;
# }
# .pill{
# 	padding:2px 4px;
# 	border-radius: 100px;
# 	background-color:#e65858;
# 	font-size:12px;
# 	font-weight:bold;
# 	margin: 0 15px;
# 	color:white;
# }
# </style>
# <details class="choice-section">
# 	<summary style="cursor:pointer">
# ...

# %%
# !HYDRA_FULL_ERROR=1 python train.py
# Out:
# /usr/local/lib/python3.7/dist-packages/hydra/_internal/defaults_list.py:251: UserWarning: In 'train.yaml': Defaults list is missing `_self_`. See https://hydra.cc/docs/upgrades/1.0_to_1.1/default_composition_order for more information
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/utilities/distributed.py:391: LightningDeprecationWarning: pytorch_lightning.utilities.distributed.rank_zero_info has been deprecated in v1.6 and will be removed in v1.8. Use the equivalent function from the pytorch_lightning.utilities.rank_zero module instead.
#   "pytorch_lightning.utilities.distributed.rank_zero_info has been deprecated in v1.6"
# dataset:
#   _target_: src.dataset.MultiModalDataset
#   data_path: /content/path_data/path_train2.pkl
#   pretrained_hubert: /content/checkpoint/hubert_large/checkpoint-6425-77
#   pretrained_roberta: /content/checkpoint/roberta_large/checkpoint-4110
#   audio_max_length: 80000
#   text_max_length: 249
# ...
